# %% [markdown]
# # Digit recognition using logistic regression

# %%
from sklearn.datasets import load_digits
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import numpy as np 
import seaborn as sns
from sklearn import metrics

# %% [markdown]
# ### loading digit dataset

# %%
digits = load_digits()
plt.figure(figsize=(20,4))
for index, (image, label) in enumerate(zip(digits.data[0:5], digits.target[0:5])):
    plt.subplot(1, 5, index + 1)
    plt.imshow(np.reshape(image, (8,8)), cmap=plt.cm.gray)

# %% [markdown]
# ### Training data splitting

# %%
x_train, x_test, y_train, y_test = train_test_split(digits.data, digits.target, test_size=0.3, random_state=25)
x_train = x_train/255
x_test = x_test/255

# %% [markdown]
# ### Model training

# %%
cls = LogisticRegression()
cls.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ### Evaluating model

# %%
predictions=cls.predict(x_test)
plt.figure(figsize=(20,4))
for index, (image, label) in enumerate(zip(x_test[0:5], y_test[0:5])):
    plt.subplot(1, 5, index + 1)
    plt.imshow(np.reshape(image, (8,8)), cmap=plt.cm.gray)
print(y_test[0:5])
# Out:
# [4 0 2 4 0]

# %%
score = cls.score(x_test, y_test)
print(score)
# Out:
# 0.8796296296296297

# %%
cm = metrics.confusion_matrix(y_test, predictions)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score: 0.8796296296296297')
